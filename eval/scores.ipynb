# %%
import sys, os
sys.path.append("..")

from evaluation import SCORES, compute_plot_cm
scores = SCORES()

# %%
models = ["vgg16", "googlenet", "dit", "layoutlmv2", "layoutlmv3", "gvdoc"]

for m in models:
    print ("=======================================================")
    print (f"======================== {m} ========================")
    print ("=======================================================")
    file1 = f"logs/idood_{m}.json"
    file2 = f"logs/ood_{m}.json"
    file3 = f"logs/rvlcdip_{m}.json"
    scores (file1, file2, False)
    print ("++++++++++++++")
    scores(file3, file2, False)
# Out:
# =======================================================
# ======================== vgg16 ========================
# =======================================================
# idood_vgg16.json
# micro_acc:0.5709  macro_acc:0.5519
# ood_vgg16.json
# |   AUC: MSP    |   AUC:Energy  ||   FPR95: MSP   |  FPR95:Energy |
# | Micro | Macro | Micro | Macro ||  Micro | Macro | Micro | Macro |
# | 0.649 | 0.706 | 0.648 | 0.707 ||  0.916 | 0.858 | 0.912 | 0.845 |
# ++++++++++++++
# rvlcdip_vgg16.json
# micro_acc:0.9078  macro_acc:0.9076
# ood_vgg16.json
# |   AUC: MSP    |   AUC:Energy  ||   FPR95: MSP   |  FPR95:Energy |
# | Micro | Macro | Micro | Macro ||  Micro | Macro | Micro | Macro |
# | 0.881 | 0.895 | 0.922 | 0.930 ||  0.649 | 0.533 | 0.465 | 0.391 |
# =======================================================
# ======================== googlenet ========================
# =======================================================
# idood_googlenet.json
# micro_acc:0.6018  macro_acc:0.6105
# ood_googlenet.json
# |   AUC: MSP    |   AUC:Energy  ||   FPR95: MSP   |  FPR95:Energy |
# | Micro | Macro | Micro | Macro ||  Micro | Macro | Micro | Macro |
# | 0.592 | 0.679 | 0.587 | 0.689 ||  0.947 | 0.869 | 0.943 | 0.845 |
# ++++++++++++++
# rvlcdip_googlenet.json
# micro_acc:0.8713  macro_acc:0.8709
# ood_googlenet.json
# |   AUC: MSP    |   AUC:Energy  ||   FPR95: MSP   |  FPR95:Energy |
# | Micro | Macro | Micro | Macro ||  Micro | Macro | Micro | Macro |
# | 0.838 | 0.859 | 0.847 | 0.869 ||  0.748 | 0.620 | 0.665 | 0.560 |
# =======================================================
# ======================== dit ========================
# =======================================================
# idood_dit.json
# micro_acc:0.7864  macro_acc:0.8051
# ood_dit.json
# |   AUC: MSP    |   AUC:Energy  ||   FPR95: MSP   |  FPR95:Energy |
# | Micro | Macro | Micro | Macro ||  Micro | Macro | Micro | Macro |
# | 0.728 | 0.780 | 0.753 | 0.792 ||  0.847 | 0.704 | 0.843 | 0.685 |
# ++++++++++++++
# rvlcdip_dit.json
# micro_acc:0.9334  macro_acc:0.9333
# ood_dit.json
# |   AUC: MSP    |   AUC:Energy  ||   FPR95: MSP   |  FPR95:Energy |
# | Micro | Macro | Micro | Macro ||  Micro | Macro | Micro | Macro |
# | 0.893 | 0.902 | 0.888 | 0.902 ||  0.587 | 0.463 | 0.499 | 0.417 |
# =======================================================
# ======================== layoutlmv2 ========================
# =======================================================
# idood_layoutlmv2.json
# micro_acc:0.5559  macro_acc:0.5956
# ood_layoutlmv2.json
# |   AUC: MSP    |   AUC:Energy  ||   FPR95: MSP   |  FPR95:Energy |
# | Micro | Macro | Micro | Macro ||  Micro | Macro | Micro | Macro |
# | 0.620 | 0.717 | 0.643 | 0.716 ||  0.932 | 0.848 | 0.939 | 0.847 |
# ++++++++++++++
# rvlcdip_layoutlmv2.json
# micro_acc:0.8820  macro_acc:0.8817
# ood_layoutlmv2.json
# |   AUC: MSP    |   AUC:Energy  ||   FPR95: MSP   |  FPR95:Energy |
# | Micro | Macro | Micro | Macro ||  Micro | Macro | Micro | Macro |
# | 0.842 | 0.875 | 0.849 | 0.891 ||  0.717 | 0.592 | 0.753 | 0.574 |
# =======================================================
# ======================== layoutlmv3 ========================
# =======================================================
# idood_layoutlmv3.json
# micro_acc:0.8245  macro_acc:0.8385
# ood_layoutlmv3.json
# |   AUC: MSP    |   AUC:Energy  ||   FPR95: MSP   |  FPR95:Energy |
# | Micro | Macro | Micro | Macro ||  Micro | Macro | Micro | Macro |
# | 0.755 | 0.807 | 0.282 | 0.211 ||  0.839 | 0.618 | 0.999 | 0.966 |
# ++++++++++++++
# rvlcdip_layoutlmv3.json
# micro_acc:0.9311  macro_acc:0.9274
# ood_layoutlmv3.json
# |   AUC: MSP    |   AUC:Energy  ||   FPR95: MSP   |  FPR95:Energy |
# | Micro | Macro | Micro | Macro ||  Micro | Macro | Micro | Macro |
# | 0.817 | 0.889 | 0.263 | 0.176 ||  0.578 | 0.531 | 1.000 | 0.996 |
# =======================================================
# ======================== gvdoc ========================
# =======================================================
# idood_gvdoc.json
# micro_acc:0.8773  macro_acc:0.8748
# ood_gvdoc.json
# |   AUC: MSP    |   AUC:Energy  ||   FPR95: MSP   |  FPR95:Energy |
# | Micro | Macro | Micro | Macro ||  Micro | Macro | Micro | Macro |
# | 0.867 | 0.890 | 1.000 | 1.000 ||  0.655 | 0.534 | 0.000 | 0.000 |
# ++++++++++++++
# rvlcdip_gvdoc.json
# micro_acc:0.8754  macro_acc:0.8751
# ood_gvdoc.json
# |   AUC: MSP    |   AUC:Energy  ||   FPR95: MSP   |  FPR95:Energy |
# | Micro | Macro | Micro | Macro ||  Micro | Macro | Micro | Macro |
# | 0.902 | 0.911 | 1.000 | 1.000 ||  0.583 | 0.484 | 0.000 | 0.000 |

# %%
models = ["vgg16", "googlenet", "dit", "layoutlmv2", "layoutlmv3", "gvdoc"]

for m in models:
    print ("=======================================================")
    print (f"======================== {m} ========================")
    print ("=======================================================")
    file1 = f"logs/idood_{m}.json"
    file2 = f"logs/ood_{m}.json"
    file3 = f"logs/rvlcdip_{m}.json"
    scores (file1, file2, True)
    print ("++++++++++++++")
    scores(file3, file2, True)
# Out:
# =======================================================
# ======================== vgg16 ========================
# =======================================================
# idood_vgg16.json
# {'macro': {'macro_acc': 0.5518594169340468,
#            'macro_acc_scores': {'article': 0.0,
#                                 'budget': 0.7931034482758621,
#                                 'email': 0.8484848484848485,
#                                 'form': 0.7428571428571429,
#                                 'handwritten': 0.4034090909090909,
#                                 'invoice': 0.7368421052631579,
#                                 'letter': 0.9013157894736842,
#                                 'memo': 0.5531914893617021,
#                                 'publication': 0.0,
#                                 'questionnaire': 0.717948717948718,
#                                 'resume': 0.6956521739130435,
#                                 'specification': 0.22950819672131148}},
#  'micro': {'micro_acc': 0.5708582834331337}}
# ood_vgg16.json
# |   AUC: MSP    |   AUC:Energy  ||   FPR95: MSP   |  FPR95:Energy |
# | Micro | Macro | Micro | Macro ||  Micro | Macro | Micro | Macro |
# | 0.649 | 0.706 | 0.648 | 0.707 ||  0.916 | 0.858 | 0.912 | 0.845 |
# ++++++++++++++
# rvlcdip_vgg16.json
# {'macro': {'macro_acc': 0.9075663373755262,
#            'macro_acc_scores': {'advertisement': 0.9260437375745527,
#                                 'budget': 0.8982035928143712,
#                                 'email': 0.9833068362480127,
#                                 'file_folder': 0.9691333597150772,
#                                 'form': 0.8208300079808459,
#                                 'handwritten': 0.9601105845181674,
#                                 'invoice': 0.9196608800968914,
#                                 'letter': 0.8798701298701299,
#                                 'memo': 0.9273675762439807,
#                                 'news_article': 0.9139261063743402,
#                                 'presentation': 0.8344716753716352,
#                                 'questionnaire': 0.8685831622176592,
#                                 'resume': 0.9530942057548285,
#                                 'scientific_publication': 0.9362115908206924,
#                                 'scientific_report': 0.8010408326661329,
#                                 'specification': 0.9292071197411004}},
#  'micro': {'micro_acc': 0.9078476961924048}}
# ood_vgg16.json
# |   AUC: MSP    |   AUC:Energy  ||   FPR95: MSP   |  FPR95:Energy |
# | Micro | Macro | Micro | Macro ||  Micro | Macro | Micro | Macro |
# | 0.881 | 0.895 | 0.922 | 0.930 ||  0.649 | 0.533 | 0.465 | 0.391 |
# =======================================================
# ======================== googlenet ========================
# =======================================================
# idood_googlenet.json
# {'macro': {'macro_acc': 0.6105092694987001,
#            'macro_acc_scores': {'budget': 0.7758620689655172,
#                                 'email': 0.8181818181818182,
#                                 'form': 0.7,
#                                 'handwritten': 0.44886363636363635,
#                                 'invoice': 0.43859649122807015,
#                                 'letter': 0.8157894736842105,
#                                 'memo': 0.5531914893617021,
#                                 'news_article': 0.6162790697674418,
#                                 'questionnaire': 0.5128205128205128,
#                                 'resume': 0.6086956521739131,
#                                 'scientific_publication': 0.9230769230769231,
#                                 'specification': 0.11475409836065574}},
#  'micro': {'micro_acc': 0.6017964071856288}}
# ood_googlenet.json
# |   AUC: MSP    |   AUC:Energy  ||   FPR95: MSP   |  FPR95:Energy |
# | Micro | Macro | Micro | Macro ||  Micro | Macro | Micro | Macro |
# | 0.592 | 0.679 | 0.587 | 0.689 ||  0.947 | 0.869 | 0.943 | 0.845 |
# ++++++++++++++
# rvlcdip_googlenet.json
# {'macro': {'macro_acc': 0.870921292092435,
#            'macro_acc_scores': {'advertisement': 0.9129224652087475,
#                                 'budget': 0.8570858283433134,
#                                 'email': 0.9797297297297297,
#                                 'file_folder': 0.9453897902651365,
#                                 'form': 0.7482043096568236,
#                                 'handwritten': 0.938783570300158,
#                                 'invoice': 0.8671780379491321,
#                                 'letter': 0.8579545454545454,
#                                 'memo': 0.8952648475120385,
#                                 'news_article': 0.8712951684937068,
#                                 'presentation': 0.8200080353555644,
#                                 'questionnaire': 0.8065708418891171,
#                                 'resume': 0.9310208908159243,
#                                 'scientific_publication': 0.9031505250875146,
#                                 'scientific_report': 0.7057646116893515,
#                                 'specification': 0.8944174757281553}},
#  'micro': {'micro_acc': 0.8712967824195604}}
# ood_googlenet.json
# |   AUC: MSP    |   AUC:Energy  ||   FPR95: MSP   |  FPR95:Energy |
# | Micro | Macro | Micro | Macro ||  Micro | Macro | Micro | Macro |
# | 0.838 | 0.859 | 0.847 | 0.869 ||  0.748 | 0.620 | 0.665 | 0.560 |
# =======================================================
# ======================== dit ========================
# =======================================================
# idood_dit.json
# {'macro': {'macro_acc': 0.8050880434360294,
#            'macro_acc_scores': {'budget': 0.8620689655172413,
#                                 'email': 0.9696969696969697,
#                                 'form': 0.9142857142857143,
#                                 'handwritten': 0.6420454545454546,
#                                 'invoice': 0.8596491228070176,
#                                 'letter': 0.9539473684210527,
#                                 'memo': 0.723404255319149,
#                                 'news_article': 0.8488372093023255,
#                                 'questionnaire': 0.8205128205128205,
#                                 'resume': 0.7336956521739131,
#                                 'scientific_publication': 0.9230769230769231,
#                                 'specification': 0.4098360655737705}},
#  'micro': {'micro_acc': 0.7864271457085829}}
# ood_dit.json
# |   AUC: MSP    |   AUC:Energy  ||   FPR95: MSP   |  FPR95:Energy |
# | Micro | Macro | Micro | Macro ||  Micro | Macro | Micro | Macro |
# | 0.728 | 0.780 | 0.753 | 0.792 ||  0.847 | 0.704 | 0.843 | 0.685 |
# ++++++++++++++
# rvlcdip_dit.json
# {'macro': {'macro_acc': 0.9332566213594864,
#            'macro_acc_scores': {'advertisement': 0.945924453280318,
#                                 'budget': 0.9273453093812375,
#                                 'email': 0.989268680445151,
#                                 'file_folder': 0.9659675504550851,
#                                 'form': 0.8691141260973663,
#                                 'handwritten': 0.9620853080568721,
#                                 'invoice': 0.9406540169559952,
#                                 'letter': 0.9237012987012987,
#                                 'memo': 0.9506420545746388,
#                                 'news_article': 0.927324401136825,
#                                 'presentation': 0.8754519887505022,
#                                 'questionnaire': 0.9080082135523614,
#                                 'resume': 0.9767441860465116,
#                                 'scientific_publication': 0.9521586931155193,
#                                 'scientific_report': 0.8694955964771818,
#                                 'specification': 0.948220064724919}},
#  'micro': {'micro_acc': 0.9334483362084052}}
# ood_dit.json
# |   AUC: MSP    |   AUC:Energy  ||   FPR95: MSP   |  FPR95:Energy |
# | Micro | Macro | Micro | Macro ||  Micro | Macro | Micro | Macro |
# | 0.893 | 0.902 | 0.888 | 0.902 ||  0.587 | 0.463 | 0.499 | 0.417 |
# =======================================================
# ======================== layoutlmv2 ========================
# =======================================================
# idood_layoutlmv2.json
# {'macro': {'macro_acc': 0.5956297501142737,
#            'macro_acc_scores': {'budget': 0.896551724137931,
#                                 'email': 0.8484848484848485,
#                                 'form': 0.5285714285714286,
#                                 'handwritten': 0.26136363636363635,
#                                 'invoice': 0.3333333333333333,
#                                 'letter': 0.8355263157894737,
#                                 'memo': 0.5106382978723404,
#                                 'news_article': 0.5116279069767442,
#                                 'questionnaire': 0.7692307692307693,
#                                 'resume': 0.5652173913043478,
#                                 'scientific_publication': 0.9230769230769231,
#                                 'specification': 0.16393442622950818}},
#  'micro': {'micro_acc': 0.5558882235528942}}
# ood_layoutlmv2.json
# |   AUC: MSP    |   AUC:Energy  ||   FPR95: MSP   |  FPR95:Energy |
# | Micro | Macro | Micro | Macro ||  Micro | Macro | Micro | Macro |
# | 0.620 | 0.717 | 0.643 | 0.716 ||  0.932 | 0.848 | 0.939 | 0.847 |
# ++++++++++++++
# rvlcdip_layoutlmv2.json
# {'macro': {'macro_acc': 0.8816632349972996,
#            'macro_acc_scores': {'advertisement': 0.94831013916501,
#                                 'budget': 0.9465069860279441,
#                                 'email': 0.9821144674085851,
#                                 'file_folder': 0.9184804115552038,
#                                 'form': 0.7418196328810854,
#                                 'handwritten': 0.9636650868878357,
#                                 'invoice': 0.828825191764231,
#                                 'letter': 0.8798701298701299,
#                                 'memo': 0.9004815409309791,
#                                 'news_article': 0.8753552578156719,
#                                 'presentation': 0.8324628364805142,
#                                 'questionnaire': 0.8209445585215606,
#                                 'resume': 0.9251083957430035,
#                                 'scientific_publication': 0.9179307662388175,
#                                 'scientific_report': 0.7173738991192954,
#                                 'specification': 0.9073624595469255}},
#  'micro': {'micro_acc': 0.8820470511762795}}
# ood_layoutlmv2.json
# |   AUC: MSP    |   AUC:Energy  ||   FPR95: MSP   |  FPR95:Energy |
# | Micro | Macro | Micro | Macro ||  Micro | Macro | Micro | Macro |
# | 0.842 | 0.875 | 0.849 | 0.891 ||  0.717 | 0.592 | 0.753 | 0.574 |
# =======================================================
# ======================== layoutlmv3 ========================
# =======================================================
# idood_layoutlmv3.json
# {'macro': {'macro_acc': 0.8384827076545974,
#            'macro_acc_scores': {'budget': 0.9120879120879121,
#                                 'email': 0.90625,
#                                 'form': 0.9191919191919192,
#                                 'handwritten': 0.2565789473684211,
#                                 'invoice': 0.9230769230769231,
#                                 'letter': 0.9251700680272109,
#                                 'memo': 0.7619047619047619,
#                                 'news article': 0.7777777777777778,
#                                 'questionnaire': 0.9787234042553191,
#                                 'resume': 0.9535714285714286,
#                                 'scientific publication': 0.9791666666666666,
#                                 'specification': 0.7682926829268293}},
#  'micro': {'micro_acc': 0.8244638602065131}}
# ood_layoutlmv3.json
# |   AUC: MSP    |   AUC:Energy  ||   FPR95: MSP   |  FPR95:Energy |
# | Micro | Macro | Micro | Macro ||  Micro | Macro | Micro | Macro |
# | 0.755 | 0.807 | 0.282 | 0.211 ||  0.839 | 0.618 | 0.999 | 0.966 |
# ++++++++++++++
# rvlcdip_layoutlmv3.json
# {'macro': {'macro_acc': 0.9273935229136051,
#            'macro_acc_scores': {'advertisement': 0.9230440359127833,
#                                 'budget': 0.9182087342709104,
#                                 'email': 0.9837638376383764,
#                                 'file folder': 0.9541945445187854,
#                                 'form': 0.8486171761280932,
#                                 'handwritten': 0.9513951395139514,
#                                 'invoice': 0.9181102362204724,
#                                 'letter': 0.9074990483441188,
#                                 'memo': 0.9374766005241483,
#                                 'news article': 0.9241379310344827,
#                                 'presentation': 0.8883566691230655,
#                                 'questionnaire': 0.9230233368164402,
#                                 'resume': 0.9829302987197724,
#                                 'scientific publication': 0.9655400927766733,
#                                 'scientific report': 0.8611111111111112,
#                                 'specification': 0.9508875739644971}},
#  'micro': {'micro_acc': 0.9311468646864687}}
# ood_layoutlmv3.json
# |   AUC: MSP    |   AUC:Energy  ||   FPR95: MSP   |  FPR95:Energy |
# | Micro | Macro | Micro | Macro ||  Micro | Macro | Micro | Macro |
# | 0.817 | 0.889 | 0.263 | 0.176 ||  0.578 | 0.531 | 1.000 | 0.996 |
# =======================================================
# ======================== gvdoc ========================
# =======================================================
# idood_gvdoc.json
# {'macro': {'macro_acc': 0.8748082275385108,
#            'macro_acc_scores': {'budget': 0.9473684210526315,
#                                 'email': 0.8275862068965517,
#                                 'form': 0.855072463768116,
#                                 'handwritten': 0.7972972972972973,
#                                 'invoice': 0.9298245614035088,
#                                 'letter': 0.943089430894309,
#                                 'memo': 0.8484848484848485,
#                                 'news article': 0.8433734939759037,
#                                 'questionnaire': 0.9743589743589743,
#                                 'resume': 0.9402173913043478,
#                                 'scientific publication': 0.9743589743589743,
#                                 'specification': 0.6166666666666667}},
#  'micro': {'micro_acc': 0.8773072747014115}}
# ood_gvdoc.json
# |   AUC: MSP    |   AUC:Energy  ||   FPR95: MSP   |  FPR95:Energy |
# | Micro | Macro | Micro | Macro ||  Micro | Macro | Micro | Macro |
# | 0.867 | 0.890 | 1.000 | 1.000 ||  0.655 | 0.534 | 0.000 | 0.000 |
# ++++++++++++++
# rvlcdip_gvdoc.json
# {'macro': {'macro_acc': 0.875074266542834,
#            'macro_acc_scores': {'advertisement': 0.7839039573143619,
#                                 'budget': 0.8553971486761711,
#                                 'email': 0.9721559268098647,
#                                 'file folder': 0.899021123132406,
#                                 'form': 0.7912308930008045,
#                                 'handwritten': 0.8918302145139206,
#                                 'invoice': 0.882137030995106,
#                                 'letter': 0.8612929623567921,
#                                 'memo': 0.8989037758830695,
#                                 'news article': 0.8604081632653061,
#                                 'presentation': 0.8161943319838056,
#                                 'questionnaire': 0.8801670146137787,
#                                 'resume': 0.9707740916271722,
#                                 'scientific publication': 0.902696365767878,
#                                 'scientific report': 0.8163430420711975,
#                                 'specification': 0.9187322226737099}},
#  'micro': {'micro_acc': 0.8754346810608813}}
# ood_gvdoc.json
# |   AUC: MSP    |   AUC:Energy  ||   FPR95: MSP   |  FPR95:Energy |
# | Micro | Macro | Micro | Macro ||  Micro | Macro | Micro | Macro |
# | 0.902 | 0.911 | 1.000 | 1.000 ||  0.583 | 0.484 | 0.000 | 0.000 |
